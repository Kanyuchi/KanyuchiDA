# %% [markdown]
# # Extracting `DAILY` data from API and Loading it to DB

# %% [markdown]
# As the purpose of our pipeline is to make Weather Data available for comparison to flights and airports data, in the first step we need to load the weather data in a raw form (JSON) into our database. So in later steps we can transform it to meaningful and useful tables.

# %% [markdown]
# ### General Presteps:

# %% [markdown]
# The Goal of this Notebook is to get raw JSON data for Daily and Hourly Weather for 3 airport weather stations and load it as it is to our database.
# - Find Station IDs for **defined** airports
# - Define the start and end of the period
# - get the API Key from the `.env`

# %% [markdown]
# ### Imports

# %% [markdown]
# we will need the credentials we saved in the `.env` file. We also will need SQLAlchemy and its functions

# %%
# we will need the credentials we saved in the .env file
from dotenv import dotenv_values

# We also will need SQLAlchemy and its functions
from sqlalchemy import create_engine, types
from sqlalchemy.dialects.postgresql import JSON as postgres_json

import pandas as pd

# requests library will make the API calls. 
# the json package will parse the JSON string and convert it to Python data structures
import requests
import json

# with 'datetime' we want to catch the timestamp of the API call. For the actuality reference. 
# and 'time' for slowing down a .bit
from datetime import datetime
import time

# %% [markdown]
# ### Defining Airports andd finding the Station IDs

# %% [markdown]
# For our Pipeline we will use weather data from the weather stations at the 3 highly frequented airports
# - **JFK**: John F. Kennedy Airport
# - **MIA**: Miami International Airport
# - **LAX**: Los Angeles Airport
# - **

# %% [markdown]
# To find the Station IDs for the airpors without stressing our API Call limits, we will use the   search option of the **https://meteostat.net/**
#
# Search for the names of the airports above and find the Station IDs

# %%
airport_staids = {
    'JFK': 74486
    ,'MIA': 72202
    ,'LAX': 72295
    ,'JNB': 68212
    ,'HRE': 67816
    ,'CPT': 68816
    ,'MPM': 67842
    ,'LUN': 67765
           }

# %% [markdown]
# ### Defining the period

# %% [markdown]
# Our flight Data is from 2024-01-01 until 2024-04-31. For the lectures we will use the same period for the meteostat JSON API.

# %%
period_start = "2019-01-01"
period_end = "2022-12-31"

# %% [markdown]
# ### loading API Key

# %%
config = dotenv_values()
config.keys
# Out:
# <function OrderedDict.keys>

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()
api_key = config['X-RapidAPI-Key']

# %% [markdown]
# # Part 1: Daily Station Data

# %% [markdown]
# Each API call will get 3 months of weather data for one Station ID.
#
# In the [**RapidAPI**](https://rapidapi.com/meteostat/api/meteostat/playground) interface you can find the code syntax we need to make the call.
#
# For each call we need to create a querystring with required parameters.

# %% [markdown]
# ### Objectives -  Daily Station Data:

# %% [markdown]
# - create a for-loop for the 3 airports, generating a **querystring for each API call**
# - define an empty dictionary to collect: time of the call, airport code, station id, related data
# - make the API calls using the for-loop and fill the dictionary
# - create pandas dataframe from the dictionary
# - load the DB credentials from the `.env`
# - create the engine
# - define data types for the postgresql table columns
# - using pandas import the dataframe to the Table in the Schema of the DB

# %% [markdown]
# ### Test: For-loop generating the querystrings

# %%
airport_staids
# Out:
# {'JFK': 74486,
#  'MIA': 72202,
#  'LAX': 72295,
#  'JNB': 68212,
#  'HRE': 67816,
#  'CPT': 68816,
#  'MPM': 67842,
#  'LUN': 67765}

# %%
# testing for-loop: querystring for each airport

for airport in airport_staids:
   
    querystring = {
        "station": airport_staids[airport]
        ,"start": period_start
        ,"end": period_end
        ,"model":"true"
    }
    print(airport, "\n", querystring)
# Out:
# JFK
#  {'station': 74486, 'start': '2019-01-01', 'end': '2022-12-31', 'model': 'true'}
# MIA
#  {'station': 72202, 'start': '2019-01-01', 'end': '2022-12-31', 'model': 'true'}
# LAX
#  {'station': 72295, 'start': '2019-01-01', 'end': '2022-12-31', 'model': 'true'}
# JNB
#  {'station': 68212, 'start': '2019-01-01', 'end': '2022-12-31', 'model': 'true'}
# HRE
#  {'station': 67816, 'start': '2019-01-01', 'end': '2022-12-31', 'model': 'true'}
# CPT
#  {'station': 68816, 'start': '2019-01-01', 'end': '2022-12-31', 'model': 'true'}
# MPM
#  {'station': 67842, 'start': '2019-01-01', 'end': '2022-12-31', 'model': 'true'}
# LUN
#  {'station': 67765, 'start': '2019-01-01', 'end': '2022-12-31', 'model': 'true'}

# %% [markdown]
# **possible question**: what does 'model' parameter do?
# **answer**: Check the meteostat documentation for the Daily or Hourly endpoint.

# %% [markdown]
# ### API CALL daily (per station)

# %%
#  let's catch each response in a dictionary. create an empty dictionary with the following keys:

weatherreport_dict = {'extracted_at':[], 
                'airport_code':[], 
                'station_id':[], 
                'extracted_data':[]
               }

# API CALL daily (station) - for the syntax: see the rapidapi interface

url = "https://meteostat.p.rapidapi.com/stations/daily"

headers = {
        "X-RapidAPI-Key": api_key,
        "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# for-loop for the querystrings
for airport in airport_staids:
   
    querystring = {
        "station":airport_staids[airport]
        ,"start":period_start
        ,"end":period_end
        ,"model":"true"
    }
    
    # making one call with the current querystring
    response = requests.get(url, headers=headers, params=querystring)
                
    # appending data to the dictionary:
    weatherreport_dict['extracted_at'].append(datetime.now)                # timestamp, 
    weatherreport_dict['airport_code'].append(airport)                       # airport code    
    weatherreport_dict['station_id'].append(airport_staids[airport])   # weater Station ID
    weatherreport_dict['extracted_data'].append(json.loads(response.text))   # JSON string

# %% [markdown]
# #### Checkout the filled dictionary

# %%
weatherreport_dict
# Out:
# {'extracted_at': [<function datetime.now(tz=None)>,
#   <function datetime.now(tz=None)>,
#   <function datetime.now(tz=None)>,
#   <function datetime.now(tz=None)>,
#   <function datetime.now(tz=None)>,
#   <function datetime.now(tz=None)>,
#   <function datetime.now(tz=None)>,
#   <function datetime.now(tz=None)>],
#  'airport_code': ['JFK', 'MIA', 'LAX', 'JNB', 'HRE', 'CPT', 'MPM', 'LUN'],
#  'station_id': [74486, 72202, 72295, 68212, 67816, 68816, 67842, 67765],
#  'extracted_data': [{'meta': {'generated': '2024-10-10 14:23:06'},
#    'data': [{'date': '2019-01-01',
#      'tavg': 10.4,
#      'tmin': 4.4,
#      'tmax': 15.0,
#      'prcp': 2.8,
#      'snow': 0.0,
#      'wdir': 280.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1010.8,
#      'tsun': None},
#     {'date': '2019-01-02',
#      'tavg': 3.3,
#      'tmin': 1.1,
#      'tmax': 5.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 65.0,
#      'wspd': 13.3,
#      'wpgt': None,
#      'pres': 1025.0,
#      'tsun': None},
#     {'date': '2019-01-03',
#      'tavg': 4.9,
#      'tmin': 1.1,
#      'tmax': 7.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 290.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1015.0,
#      'tsun': None},
#     {'date': '2019-01-04',
#      'tavg': 3.7,
#      'tmin': 1.1,
#      'tmax': 7.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 231.0,
#      'wspd': 18.7,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None},
#     {'date': '2019-01-05',
#      'tavg': 6.9,
#      'tmin': 5.0,
#      'tmax': 7.8,
#      'prcp': 10.2,
#      'snow': 0.0,
#      'wdir': 19.0,
#      'wspd': 19.1,
#      'wpgt': None,
#      'pres': 1001.4,
#      'tsun': None},
#     {'date': '2019-01-06',
#      'tavg': 6.6,
#      'tmin': -0.5,
#      'tmax': 10.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 296.0,
#      'wspd': 29.2,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None},
#     {'date': '2019-01-07',
#      'tavg': -1.0,
#      'tmin': -3.8,
#      'tmax': 1.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 4.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1030.2,
#      'tsun': None},
#     {'date': '2019-01-08',
#      'tavg': 4.3,
#      'tmin': 1.7,
#      'tmax': 7.8,
#      'prcp': 4.3,
#      'snow': 0.0,
#      'wdir': 176.0,
#      'wspd': 12.6,
#      'wpgt': None,
#      'pres': 1015.1,
#      'tsun': None},
#     {'date': '2019-01-09',
#      'tavg': 6.3,
#      'tmin': 1.1,
#      'tmax': 8.3,
#      'prcp': 1.8,
#      'snow': 0.0,
#      'wdir': 283.0,
#      'wspd': 34.2,
#      'wpgt': None,
#      'pres': 1002.0,
#      'tsun': None},
#     {'date': '2019-01-10',
#      'tavg': 1.2,
#      'tmin': -2.1,
#      'tmax': 2.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 301.0,
#      'wspd': 38.5,
#      'wpgt': None,
#      'pres': 1007.5,
#      'tsun': None},
#     {'date': '2019-01-11',
#      'tavg': -2.4,
#      'tmin': -5.5,
#      'tmax': 0.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 312.0,
#      'wspd': 30.6,
#      'wpgt': None,
#      'pres': 1023.3,
#      'tsun': None},
#     {'date': '2019-01-12',
#      'tavg': -3.3,
#      'tmin': -6.6,
#      'tmax': 1.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 335.0,
#      'wspd': 10.4,
#      'wpgt': None,
#      'pres': 1033.2,
#      'tsun': None},
#     {'date': '2019-01-13',
#      'tavg': -1.6,
#      'tmin': -4.3,
#      'tmax': 0.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 28.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1029.5,
#      'tsun': None},
#     {'date': '2019-01-14',
#      'tavg': -2.5,
#      'tmin': -4.3,
#      'tmax': 0.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 359.0,
#      'wspd': 19.4,
#      'wpgt': None,
#      'pres': 1023.7,
#      'tsun': None},
#     {'date': '2019-01-15',
#      'tavg': -1.8,
#      'tmin': -4.9,
#      'tmax': 2.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 340.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1020.7,
#      'tsun': None},
#     {'date': '2019-01-16',
#      'tavg': -0.1,
#      'tmin': -3.8,
#      'tmax': 3.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 258.0,
#      'wspd': 20.9,
#      'wpgt': None,
#      'pres': 1019.2,
#      'tsun': None},
#     {'date': '2019-01-17',
#      'tavg': -0.6,
#      'tmin': -3.8,
#      'tmax': 1.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 15.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1027.4,
#      'tsun': None},
#     {'date': '2019-01-18',
#      'tavg': 0.4,
#      'tmin': -2.1,
#      'tmax': 3.9,
#      'prcp': 1.0,
#      'snow': 30.0,
#      'wdir': 326.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1020.3,
#      'tsun': None},
#     {'date': '2019-01-19',
#      'tavg': 1.6,
#      'tmin': -1.6,
#      'tmax': 3.9,
#      'prcp': 10.4,
#      'snow': 0.0,
#      'wdir': 46.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1021.4,
#      'tsun': None},
#     {'date': '2019-01-20',
#      'tavg': 3.2,
#      'tmin': -9.3,
#      'tmax': 10.0,
#      'prcp': 31.2,
#      'snow': 0.0,
#      'wdir': 2.0,
#      'wspd': 31.7,
#      'wpgt': None,
#      'pres': 999.4,
#      'tsun': None},
#     {'date': '2019-01-21',
#      'tavg': -11.1,
#      'tmin': -14.9,
#      'tmax': -9.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 298.0,
#      'wspd': 44.3,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None},
#     {'date': '2019-01-22',
#      'tavg': -7.4,
#      'tmin': -9.9,
#      'tmax': -0.5,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 282.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1035.8,
#      'tsun': None},
#     {'date': '2019-01-23',
#      'tavg': 1.0,
#      'tmin': -1.6,
#      'tmax': 8.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 198.0,
#      'wspd': 22.0,
#      'wpgt': None,
#      'pres': 1025.3,
#      'tsun': None},
#     {'date': '2019-01-24',
#      'tavg': 8.4,
#      'tmin': 1.7,
#      'tmax': 12.2,
#      'prcp': 34.8,
#      'snow': 0.0,
#      'wdir': 215.0,
#      'wspd': 34.2,
#      'wpgt': None,
#      'pres': 1002.9,
#      'tsun': None},
#     {'date': '2019-01-25',
#      'tavg': 2.5,
#      'tmin': -2.1,
#      'tmax': 4.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 274.0,
#      'wspd': 26.6,
#      'wpgt': None,
#      'pres': 1015.1,
#      'tsun': None},
#     {'date': '2019-01-26',
#      'tavg': -1.6,
#      'tmin': -4.3,
#      'tmax': 0.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 232.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1024.6,
#      'tsun': None},
#     {'date': '2019-01-27',
#      'tavg': 2.8,
#      'tmin': -2.1,
#      'tmax': 7.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 173.0,
#      'wspd': 23.4,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None},
#     {'date': '2019-01-28',
#      'tavg': 0.2,
#      'tmin': -4.9,
#      'tmax': 3.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 356.0,
#      'wspd': 18.0,
#      'wpgt': None,
#      'pres': 1018.2,
#      'tsun': None},
#     {'date': '2019-01-29',
#      'tavg': -0.7,
#      'tmin': -5.5,
#      'tmax': 6.1,
#      'prcp': 5.3,
#      'snow': 0.0,
#      'wdir': 81.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1013.8,
#      'tsun': None},
#     {'date': '2019-01-30',
#      'tavg': -1.4,
#      'tmin': -13.8,
#      'tmax': 1.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 268.0,
#      'wspd': 33.8,
#      'wpgt': None,
#      'pres': 1014.3,
#      'tsun': None},
#     {'date': '2019-01-31',
#      'tavg': -12.8,
#      'tmin': -16.0,
#      'tmax': -8.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 273.0,
#      'wspd': 26.6,
#      'wpgt': None,
#      'pres': 1028.6,
#      'tsun': None},
#     {'date': '2019-02-01',
#      'tavg': -9.1,
#      'tmin': -11.6,
#      'tmax': -5.5,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 279.0,
#      'wspd': 15.8,
#      'wpgt': None,
#      'pres': 1030.2,
#      'tsun': None},
#     {'date': '2019-02-02',
#      'tavg': -5.2,
#      'tmin': -8.8,
#      'tmax': 0.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 255.0,
#      'wspd': 19.8,
#      'wpgt': None,
#      'pres': 1024.9,
#      'tsun': None},
#     {'date': '2019-02-03',
#      'tavg': 1.7,
#      'tmin': -3.8,
#      'tmax': 9.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 212.0,
#      'wspd': 11.9,
#      'wpgt': None,
#      'pres': 1020.9,
#      'tsun': None},
#     {'date': '2019-02-04',
#      'tavg': 4.2,
#      'tmin': -1.0,
#      'tmax': 11.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 177.0,
#      'wspd': 7.9,
#      'wpgt': None,
#      'pres': 1018.4,
#      'tsun': None},
#     {'date': '2019-02-05',
#      'tavg': 5.9,
#      'tmin': 0.0,
#      'tmax': 15.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 219.0,
#      'wspd': 9.7,
#      'wpgt': None,
#      'pres': 1015.4,
#      'tsun': None},
#     {'date': '2019-02-06',
#      'tavg': 5.7,
#      'tmin': 0.6,
#      'tmax': 7.2,
#      'prcp': 12.7,
#      'snow': 0.0,
#      'wdir': 61.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1021.6,
#      'tsun': None},
#     {'date': '2019-02-07',
#      'tavg': 5.1,
#      'tmin': 3.9,
#      'tmax': 6.7,
#      'prcp': 3.8,
#      'snow': 0.0,
#      'wdir': 42.0,
#      'wspd': 14.4,
#      'wpgt': None,
#      'pres': 1018.3,
#      'tsun': None},
#     {'date': '2019-02-08',
#      'tavg': 6.3,
#      'tmin': 0.0,
#      'tmax': 12.8,
#      'prcp': 3.8,
#      'snow': 0.0,
#      'wdir': 240.0,
#      'wspd': 24.5,
#      'wpgt': None,
#      'pres': 1015.4,
#      'tsun': None},
#     {'date': '2019-02-09',
#      'tavg': -0.4,
#      'tmin': -4.3,
#      'tmax': 1.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 308.0,
#      'wspd': 33.8,
#      'wpgt': None,
#      'pres': 1034.6,
#      'tsun': None},
#     {'date': '2019-02-10',
#      'tavg': -2.0,
#      'tmin': -5.5,
#      'tmax': 1.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 280.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1035.9,
#      'tsun': None},
#     {'date': '2019-02-11',
#      'tavg': 0.8,
#      'tmin': -1.6,
#      'tmax': 2.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 22.0,
#      'wspd': 9.7,
#      'wpgt': None,
#      'pres': 1027.0,
#      'tsun': None},
#     {'date': '2019-02-12',
#      'tavg': -0.4,
#      'tmin': -3.2,
#      'tmax': 2.8,
#      'prcp': 21.8,
#      'snow': 0.0,
#      'wdir': 56.0,
#      'wspd': 23.8,
#      'wpgt': None,
#      'pres': 1022.8,
#      'tsun': None},
#     {'date': '2019-02-13',
#      'tavg': 2.8,
#      'tmin': 0.6,
#      'tmax': 5.6,
#      'prcp': 0.8,
#      'snow': 30.0,
#      'wdir': 279.0,
#      'wspd': 26.6,
#      'wpgt': None,
#      'pres': 1005.9,
#      'tsun': None},
#     {'date': '2019-02-14',
#      'tavg': 2.8,
#      'tmin': 0.6,
#      'tmax': 7.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 253.0,
#      'wspd': 22.7,
#      'wpgt': None,
#      'pres': 1016.4,
#      'tsun': None},
#     {'date': '2019-02-15',
#      'tavg': 6.3,
#      'tmin': 3.3,
#      'tmax': 12.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 178.0,
#      'wspd': 26.3,
#      'wpgt': None,
#      'pres': 1008.3,
#      'tsun': None},
#     {'date': '2019-02-16',
#      'tavg': 5.6,
#      'tmin': 0.0,
#      'tmax': 11.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 328.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1011.1,
#      'tsun': None},
#     {'date': '2019-02-17',
#      'tavg': -0.3,
#      'tmin': -3.8,
#      'tmax': 2.2,
#      'prcp': 1.0,
#      'snow': 0.0,
#      'wdir': 71.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1018.9,
#      'tsun': None},
#     {'date': '2019-02-18',
#      'tavg': 2.3,
#      'tmin': -3.2,
#      'tmax': 6.1,
#      'prcp': 2.3,
#      'snow': 0.0,
#      'wdir': 337.0,
#      'wspd': 22.7,
#      'wpgt': None,
#      'pres': 1014.3,
#      'tsun': None},
#     {'date': '2019-02-19',
#      'tavg': -1.7,
#      'tmin': -4.9,
#      'tmax': 2.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 314.0,
#      'wspd': 22.0,
#      'wpgt': None,
#      'pres': 1033.7,
#      'tsun': None},
#     {'date': '2019-02-20',
#      'tavg': -1.7,
#      'tmin': -3.2,
#      'tmax': 1.1,
#      'prcp': 16.8,
#      'snow': 0.0,
#      'wdir': 66.0,
#      'wspd': 11.5,
#      'wpgt': None,
#      'pres': 1032.6,
#      'tsun': None},
#     {'date': '2019-02-21',
#      'tavg': 3.7,
#      'tmin': 0.6,
#      'tmax': 10.6,
#      'prcp': 4.3,
#      'snow': 30.0,
#      'wdir': 283.0,
#      'wspd': 20.2,
#      'wpgt': None,
#      'pres': 1015.3,
#      'tsun': None},
#     {'date': '2019-02-22',
#      'tavg': 6.1,
#      'tmin': 2.8,
#      'tmax': 7.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 333.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1027.2,
#      'tsun': None},
#     {'date': '2019-02-23',
#      'tavg': 2.6,
#      'tmin': -0.5,
#      'tmax': 4.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 68.0,
#      'wspd': 11.9,
#      'wpgt': None,
#      'pres': 1030.2,
#      'tsun': None},
#     {'date': '2019-02-24',
#      'tavg': 5.6,
#      'tmin': 3.3,
#      'tmax': 8.3,
#      'prcp': 22.9,
#      'snow': 0.0,
#      'wdir': 163.0,
#      'wspd': 24.8,
#      'wpgt': None,
#      'pres': 1004.4,
#      'tsun': None},
#     {'date': '2019-02-25',
#      'tavg': 5.2,
#      'tmin': -2.1,
#      'tmax': 6.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 281.0,
#      'wspd': 47.2,
#      'wpgt': None,
#      'pres': 1009.4,
#      'tsun': None},
#     {'date': '2019-02-26',
#      'tavg': -0.3,
#      'tmin': -3.2,
#      'tmax': 3.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 304.0,
#      'wspd': 28.4,
#      'wpgt': None,
#      'pres': 1027.2,
#      'tsun': None},
#     {'date': '2019-02-27',
#      'tavg': -3.1,
#      'tmin': -4.3,
#      'tmax': -1.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 68.0,
#      'wspd': 13.3,
#      'wpgt': None,
#      'pres': 1027.1,
#      'tsun': None},
#     {'date': '2019-02-28',
#      'tavg': -0.7,
#      'tmin': -2.7,
#      'tmax': 2.8,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 12.0,
#      'wspd': 19.4,
#      'wpgt': None,
#      'pres': 1020.9,
#      'tsun': None},
#     {'date': '2019-03-01',
#      'tavg': -0.4,
#      'tmin': -2.7,
#      'tmax': 2.8,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 49.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1026.3,
#      'tsun': None},
#     {'date': '2019-03-02',
#      'tavg': 1.1,
#      'tmin': -0.5,
#      'tmax': 4.4,
#      'prcp': 14.2,
#      'snow': 80.0,
#      'wdir': 331.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1017.9,
#      'tsun': None},
#     {'date': '2019-03-03',
#      'tavg': 3.3,
#      'tmin': 0.0,
#      'tmax': 6.1,
#      'prcp': 14.5,
#      'snow': 30.0,
#      'wdir': 334.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1018.2,
#      'tsun': None},
#     {'date': '2019-03-04',
#      'tavg': 1.5,
#      'tmin': -1.6,
#      'tmax': 3.9,
#      'prcp': 11.2,
#      'snow': 50.0,
#      'wdir': 326.0,
#      'wspd': 24.8,
#      'wpgt': None,
#      'pres': 1009.0,
#      'tsun': None},
#     {'date': '2019-03-05',
#      'tavg': -2.2,
#      'tmin': -6.6,
#      'tmax': 0.6,
#      'prcp': 0.0,
#      'snow': 30.0,
#      'wdir': 280.0,
#      'wspd': 22.7,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None},
#     {'date': '2019-03-06',
#      'tavg': -4.2,
#      'tmin': -7.1,
#      'tmax': -2.1,
#      'prcp': 0.0,
#      'snow': 30.0,
#      'wdir': 295.0,
#      'wspd': 28.8,
#      'wpgt': None,
#      'pres': 1020.6,
#      'tsun': None},
#     {'date': '2019-03-07',
#      'tavg': -4.0,
#      'tmin': -7.7,
#      'tmax': 0.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 288.0,
#      'wspd': 21.6,
#      'wpgt': None,
#      'pres': 1026.3,
#      'tsun': None},
#     {'date': '2019-03-08',
#      'tavg': -1.4,
#      'tmin': -5.5,
#      'tmax': 2.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 148.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1028.1,
#      'tsun': None},
#     {'date': '2019-03-09',
#      'tavg': 3.3,
#      'tmin': 0.6,
#      'tmax': 8.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 214.0,
#      'wspd': 11.9,
#      'wpgt': None,
#      'pres': 1026.1,
#      'tsun': None},
#     {'date': '2019-03-10',
#      'tavg': 3.7,
#      'tmin': 1.7,
#      'tmax': 6.7,
#      'prcp': 22.1,
#      'snow': 0.0,
#      'wdir': 44.0,
#      'wspd': 19.8,
#      'wpgt': None,
#      'pres': 1018.8,
#      'tsun': None},
#     {'date': '2019-03-11',
#      'tavg': 8.1,
#      'tmin': 3.9,
#      'tmax': 12.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 270.0,
#      'wspd': 27.0,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None},
#     {'date': '2019-03-12',
#      'tavg': 4.9,
#      'tmin': 1.1,
#      'tmax': 7.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 316.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1022.3,
#      'tsun': None},
#     {'date': '2019-03-13',
#      'tavg': 2.4,
#      'tmin': -1.6,
#      'tmax': 5.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 156.0,
#      'wspd': 12.6,
#      'wpgt': None,
#      'pres': 1027.7,
#      'tsun': None},
#     {'date': '2019-03-14',
#      'tavg': 6.6,
#      'tmin': 3.3,
#      'tmax': 11.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 156.0,
#      'wspd': 19.4,
#      'wpgt': None,
#      'pres': 1022.8,
#      'tsun': None},
#     {'date': '2019-03-15',
#      'tavg': 9.6,
#      'tmin': 8.3,
#      'tmax': 15.0,
#      'prcp': 4.1,
#      'snow': 0.0,
#      'wdir': 183.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1009.9,
#      'tsun': None},
#     {'date': '2019-03-16',
#      'tavg': 10.1,
#      'tmin': 2.8,
#      'tmax': 13.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 285.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None},
#     {'date': '2019-03-17',
#      'tavg': 4.1,
#      'tmin': 0.6,
#      'tmax': 7.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 299.0,
#      'wspd': 21.2,
#      'wpgt': None,
#      'pres': 1022.0,
#      'tsun': None},
#     {'date': '2019-03-18',
#      'tavg': 2.9,
#      'tmin': -2.1,
#      'tmax': 7.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 287.0,
#      'wspd': 12.6,
#      'wpgt': None,
#      'pres': 1025.5,
#      'tsun': None},
#     {'date': '2019-03-19',
#      'tavg': 4.0,
#      'tmin': 0.0,
#      'tmax': 10.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 250.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1029.6,
#      'tsun': None},
#     {'date': '2019-03-20',
#      'tavg': 4.5,
#      'tmin': -0.5,
#      'tmax': 10.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 178.0,
#      'wspd': 13.7,
#      'wpgt': None,
#      'pres': 1028.8,
#      'tsun': None},
#     {'date': '2019-03-21',
#      'tavg': 6.8,
#      'tmin': 5.0,
#      'tmax': 8.9,
#      'prcp': 16.0,
#      'snow': 0.0,
#      'wdir': 87.0,
#      'wspd': 23.0,
#      'wpgt': None,
#      'pres': 1017.0,
#      'tsun': None},
#     {'date': '2019-03-22',
#      'tavg': 7.3,
#      'tmin': 3.9,
#      'tmax': 10.6,
#      'prcp': 15.0,
#      'snow': 0.0,
#      'wdir': 330.0,
#      'wspd': 35.6,
#      'wpgt': None,
#      'pres': 995.3,
#      'tsun': None},
#     {'date': '2019-03-23',
#      'tavg': 5.1,
#      'tmin': 1.7,
#      'tmax': 10.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 295.0,
#      'wspd': 39.6,
#      'wpgt': None,
#      'pres': 1010.0,
#      'tsun': None},
#     {'date': '2019-03-24',
#      'tavg': 7.3,
#      'tmin': 2.8,
#      'tmax': 14.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 254.0,
#      'wspd': 19.8,
#      'wpgt': None,
#      'pres': 1020.4,
#      'tsun': None},
#     {'date': '2019-03-25',
#      'tavg': 10.5,
#      'tmin': 5.6,
#      'tmax': 12.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 310.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1017.7,
#      'tsun': None},
#     {'date': '2019-03-26',
#      'tavg': 5.3,
#      'tmin': 0.0,
#      'tmax': 8.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 8.0,
#      'wspd': 24.5,
#      'wpgt': None,
#      'pres': 1023.9,
#      'tsun': None},
#     {'date': '2019-03-27',
#      'tavg': 3.5,
#      'tmin': 0.0,
#      'tmax': 5.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 93.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1032.9,
#      'tsun': None},
#     {'date': '2019-03-28',
#      'tavg': 4.2,
#      'tmin': 0.6,
#      'tmax': 8.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 180.0,
#      'wspd': 20.2,
#      'wpgt': None,
#      'pres': 1029.5,
#      'tsun': None},
#     {'date': '2019-03-29',
#      'tavg': 8.4,
#      'tmin': 6.7,
#      'tmax': 13.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 187.0,
#      'wspd': 11.5,
#      'wpgt': None,
#      'pres': 1020.5,
#      'tsun': None},
#     {'date': '2019-03-30',
#      'tavg': 10.6,
#      'tmin': 8.3,
#      'tmax': 13.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 145.0,
#      'wspd': 24.8,
#      'wpgt': None,
#      'pres': 1016.9,
#      'tsun': None},
#     {'date': '2019-03-31',
#      'tavg': 9.8,
#      'tmin': 3.9,
#      'tmax': 13.3,
#      'prcp': 2.8,
#      'snow': 0.0,
#      'wdir': 224.0,
#      'wspd': 31.0,
#      'wpgt': None,
#      'pres': 1008.0,
#      'tsun': None},
#     {'date': '2019-04-01',
#      'tavg': 4.4,
#      'tmin': 0.0,
#      'tmax': 8.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 314.0,
#      'wspd': 27.0,
#      'wpgt': None,
#      'pres': 1021.8,
#      'tsun': None},
#     {'date': '2019-04-02',
#      'tavg': 4.7,
#      'tmin': -0.5,
#      'tmax': 9.4,
#      'prcp': 1.3,
#      'snow': 0.0,
#      'wdir': 101.0,
#      'wspd': 18.7,
#      'wpgt': None,
#      'pres': 1027.5,
#      'tsun': None},
#     {'date': '2019-04-03',
#      'tavg': 9.8,
#      'tmin': 4.4,
#      'tmax': 18.9,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 294.0,
#      'wspd': 32.0,
#      'wpgt': None,
#      'pres': 1016.3,
#      'tsun': None},
#     {'date': '2019-04-04',
#      'tavg': 11.4,
#      'tmin': 5.6,
#      'tmax': 16.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 306.0,
#      'wspd': 21.2,
#      'wpgt': None,
#      'pres': 1028.0,
#      'tsun': None},
#     {'date': '2019-04-05',
#      'tavg': 5.4,
#      'tmin': 3.3,
#      'tmax': 6.1,
#      'prcp': 5.8,
#      'snow': 0.0,
#      'wdir': 65.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1030.8,
#      'tsun': None},
#     {'date': '2019-04-06',
#      'tavg': 8.4,
#      'tmin': 4.4,
#      'tmax': 17.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 331.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1022.5,
#      'tsun': None},
#     {'date': '2019-04-07',
#      'tavg': 12.1,
#      'tmin': 7.2,
#      'tmax': 15.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 153.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1023.6,
#      'tsun': None},
#     {'date': '2019-04-08',
#      'tavg': 13.1,
#      'tmin': 8.9,
#      'tmax': 20.0,
#      'prcp': 6.9,
#      'snow': 0.0,
#      'wdir': 169.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1011.0,
#      'tsun': None},
#     {'date': '2019-04-09',
#      'tavg': 8.9,
#      'tmin': 6.1,
#      'tmax': 8.9,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 68.0,
#      'wspd': 13.7,
#      'wpgt': None,
#      'pres': 1005.6,
#      'tsun': None},
#     {'date': '2019-04-10',
#      'tavg': 10.4,
#      'tmin': 4.4,
#      'tmax': 16.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 305.0,
#      'wspd': 23.0,
#      'wpgt': None,
#      'pres': 1010.2,
#      'tsun': None},
#     {'date': '2019-04-11',
#      'tavg': 6.9,
#      'tmin': 3.3,
#      'tmax': 8.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 68.0,
#      'wspd': 12.6,
#      'wpgt': None,
#      'pres': 1023.8,
#      'tsun': None},
#     {'date': '2019-04-12',
#      'tavg': 10.3,
#      'tmin': 7.2,
#      'tmax': 16.7,
#      'prcp': 15.5,
#      'snow': 0.0,
#      'wdir': 123.0,
#      'wspd': 22.7,
#      'wpgt': None,
#      'pres': 1023.6,
#      'tsun': None},
#     {'date': '2019-04-13',
#      'tavg': 14.1,
#      'tmin': 11.7,
#      'tmax': 20.6,
#      'prcp': 9.1,
#      'snow': 0.0,
#      'wdir': 191.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1017.9,
#      'tsun': None},
#     {'date': '2019-04-14',
#      'tavg': 13.6,
#      'tmin': 10.6,
#      'tmax': 17.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 159.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1011.3,
#      'tsun': None},
#     {'date': '2019-04-15',
#      'tavg': 13.4,
#      'tmin': 7.8,
#      'tmax': 16.1,
#      'prcp': 13.2,
#      'snow': 0.0,
#      'wdir': 243.0,
#      'wspd': 39.2,
#      'wpgt': None,
#      'pres': 998.4,
#      'tsun': None},
#     {'date': '2019-04-16',
#      'tavg': 11.2,
#      'tmin': 6.7,
#      'tmax': 18.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 287.0,
#      'wspd': 29.9,
#      'wpgt': None,
#      'pres': 1014.9,
#      'tsun': None},
#     {'date': '2019-04-17',
#      'tavg': 11.8,
#      'tmin': 8.3,
#      'tmax': 13.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 102.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1021.1,
#      'tsun': None},
#     {'date': '2019-04-18',
#      'tavg': 11.1,
#      'tmin': 9.4,
#      'tmax': 14.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 130.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None},
#     {'date': '2019-04-19',
#      'tavg': 14.6,
#      'tmin': 12.2,
#      'tmax': 21.1,
#      'prcp': 0.5,
#      'snow': 0.0,
#      'wdir': 179.0,
#      'wspd': 34.9,
#      'wpgt': None,
#      'pres': 1009.8,
#      'tsun': None},
#     {'date': '2019-04-20',
#      'tavg': 14.2,
#      'tmin': 11.7,
#      'tmax': 16.7,
#      'prcp': 14.2,
#      'snow': 0.0,
#      'wdir': 163.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1008.5,
#      'tsun': None},
#     {'date': '2019-04-21',
#      'tavg': 12.8,
#      'tmin': 10.6,
#      'tmax': 16.7,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 131.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None},
#     {'date': '2019-04-22',
#      'tavg': 13.0,
#      'tmin': 10.0,
#      'tmax': 16.7,
#      'prcp': 12.2,
#      'snow': 0.0,
#      'wdir': 3.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1017.0,
#      'tsun': None},
#     {'date': '2019-04-23',
#      'tavg': 16.3,
#      'tmin': 13.3,
#      'tmax': 21.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 235.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None},
#     {'date': '2019-04-24',
#      'tavg': 17.3,
#      'tmin': 11.7,
#      'tmax': 21.1,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 297.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1007.9,
#      'tsun': None},
#     {'date': '2019-04-25',
#      'tavg': 12.3,
#      'tmin': 8.3,
#      'tmax': 14.4,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 105.0,
#      'wspd': 13.3,
#      'wpgt': None,
#      'pres': 1014.4,
#      'tsun': None},
#     {'date': '2019-04-26',
#      'tavg': 12.4,
#      'tmin': 11.1,
#      'tmax': 15.0,
#      'prcp': 28.2,
#      'snow': 0.0,
#      'wdir': 99.0,
#      'wspd': 21.6,
#      'wpgt': None,
#      'pres': 1003.7,
#      'tsun': None},
#     {'date': '2019-04-27',
#      'tavg': 12.9,
#      'tmin': 8.3,
#      'tmax': 16.1,
#      'prcp': 1.0,
#      'snow': 0.0,
#      'wdir': 299.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1001.5,
#      'tsun': None},
#     {'date': '2019-04-28',
#      'tavg': 10.2,
#      'tmin': 7.2,
#      'tmax': 12.8,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 21.0,
#      'wspd': 15.8,
#      'wpgt': None,
#      'pres': 1016.2,
#      'tsun': None},
#     {'date': '2019-04-29',
#      'tavg': 9.2,
#      'tmin': 3.9,
#      'tmax': 12.8,
#      'prcp': 1.0,
#      'snow': 0.0,
#      'wdir': 123.0,
#      'wspd': 15.8,
#      'wpgt': None,
#      'pres': 1028.0,
#      'tsun': None},
#     {'date': '2019-04-30',
#      'tavg': 10.4,
#      'tmin': 8.9,
#      'tmax': 15.0,
#      'prcp': 2.3,
#      'snow': 0.0,
#      'wdir': 118.0,
#      'wspd': 8.3,
#      'wpgt': None,
#      'pres': 1024.1,
#      'tsun': None},
#     {'date': '2019-05-01',
#      'tavg': 11.1,
#      'tmin': 9.4,
#      'tmax': 12.2,
#      'prcp': 0.5,
#      'snow': 0.0,
#      'wdir': 104.0,
#      'wspd': 13.7,
#      'wpgt': None,
#      'pres': 1028.9,
#      'tsun': None},
#     {'date': '2019-05-02',
#      'tavg': 12.4,
#      'tmin': 9.4,
#      'tmax': 21.1,
#      'prcp': 4.6,
#      'snow': 0.0,
#      'wdir': 128.0,
#      'wspd': 14.4,
#      'wpgt': None,
#      'pres': 1020.9,
#      'tsun': None},
#     {'date': '2019-05-03',
#      'tavg': 10.9,
#      'tmin': 9.4,
#      'tmax': 13.3,
#      'prcp': 5.3,
#      'snow': 0.0,
#      'wdir': 63.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1019.3,
#      'tsun': None},
#     {'date': '2019-05-04',
#      'tavg': 13.6,
#      'tmin': 11.7,
#      'tmax': 18.3,
#      'prcp': 2.5,
#      'snow': 0.0,
#      'wdir': 99.0,
#      'wspd': 9.7,
#      'wpgt': None,
#      'pres': 1012.1,
#      'tsun': None},
#     {'date': '2019-05-05',
#      'tavg': 12.8,
#      'tmin': 10.6,
#      'tmax': 13.9,
#      'prcp': 38.6,
#      'snow': 0.0,
#      'wdir': 52.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1009.9,
#      'tsun': None},
#     {'date': '2019-05-06',
#      'tavg': 13.2,
#      'tmin': 10.0,
#      'tmax': 20.0,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 71.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1015.1,
#      'tsun': None},
#     {'date': '2019-05-07',
#      'tavg': 13.2,
#      'tmin': 10.6,
#      'tmax': 16.7,
#      'prcp': 1.0,
#      'snow': 0.0,
#      'wdir': 167.0,
#      'wspd': 16.2,
#      'wpgt': None,
#      'pres': 1021.4,
#      'tsun': None},
#     {'date': '2019-05-08',
#      'tavg': 15.6,
#      'tmin': 11.1,
#      'tmax': 20.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 63.0,
#      'wspd': 13.3,
#      'wpgt': None,
#      'pres': 1022.9,
#      'tsun': None},
#     {'date': '2019-05-09',
#      'tavg': 12.1,
#      'tmin': 10.0,
#      'tmax': 13.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 88.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1026.1,
#      'tsun': None},
#     {'date': '2019-05-10',
#      'tavg': 14.3,
#      'tmin': 12.2,
#      'tmax': 19.4,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 163.0,
#      'wspd': 21.6,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None},
#     {'date': '2019-05-11',
#      'tavg': 16.9,
#      'tmin': 13.3,
#      'tmax': 21.1,
#      'prcp': 0.5,
#      'snow': 0.0,
#      'wdir': 291.0,
#      'wspd': 15.8,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None},
#     {'date': '2019-05-12',
#      'tavg': 10.5,
#      'tmin': 6.1,
#      'tmax': 13.3,
#      'prcp': 27.2,
#      'snow': 0.0,
#      'wdir': 62.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1013.9,
#      'tsun': None},
#     {'date': '2019-05-13',
#      'tavg': 7.7,
#      'tmin': 6.1,
#      'tmax': 9.4,
#      'prcp': 16.5,
#      'snow': 0.0,
#      'wdir': 49.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1011.3,
#      'tsun': None},
#     {'date': '2019-05-14',
#      'tavg': 8.4,
#      'tmin': 6.7,
#      'tmax': 10.6,
#      'prcp': 3.0,
#      'snow': 0.0,
#      'wdir': 81.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1010.1,
#      'tsun': None},
#     {'date': '2019-05-15',
#      'tavg': 11.4,
#      'tmin': 7.2,
#      'tmax': 18.9,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 284.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1010.7,
#      'tsun': None},
#     {'date': '2019-05-16',
#      'tavg': 15.6,
#      'tmin': 11.1,
#      'tmax': 20.0,
#      'prcp': 1.3,
#      'snow': 0.0,
#      'wdir': 218.0,
#      'wspd': 14.4,
#      'wpgt': None,
#      'pres': 1011.1,
#      'tsun': None},
#     {'date': '2019-05-17',
#      'tavg': 16.4,
#      'tmin': 12.2,
#      'tmax': 21.7,
#      'prcp': 6.4,
#      'snow': 0.0,
#      'wdir': 187.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1009.1,
#      'tsun': None},
#     {'date': '2019-05-18',
#      'tavg': 17.7,
#      'tmin': 13.3,
#      'tmax': 21.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 285.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None},
#     {'date': '2019-05-19',
#      'tavg': 16.4,
#      'tmin': 13.3,
#      'tmax': 20.6,
#      'prcp': 3.6,
#      'snow': 0.0,
#      'wdir': 175.0,
#      'wspd': 23.0,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None},
#     {'date': '2019-05-20',
#      'tavg': 20.4,
#      'tmin': 16.1,
#      'tmax': 30.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 202.0,
#      'wspd': 19.4,
#      'wpgt': None,
#      'pres': 1009.5,
#      'tsun': None},
#     {'date': '2019-05-21',
#      'tavg': 20.0,
#      'tmin': 14.4,
#      'tmax': 22.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 321.0,
#      'wspd': 33.1,
#      'wpgt': None,
#      'pres': 1013.0,
#      'tsun': None},
#     {'date': '2019-05-22',
#      'tavg': 18.1,
#      'tmin': 12.8,
#      'tmax': 23.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 313.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1022.6,
#      'tsun': None},
#     {'date': '2019-05-23',
#      'tavg': 16.4,
#      'tmin': 12.8,
#      'tmax': 20.6,
#      'prcp': 10.4,
#      'snow': 0.0,
#      'wdir': 189.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1019.2,
#      'tsun': None},
#     {'date': '2019-05-24',
#      'tavg': 20.4,
#      'tmin': 16.7,
#      'tmax': 23.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 305.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None},
#     {'date': '2019-05-25',
#      'tavg': 16.4,
#      'tmin': 11.7,
#      'tmax': 18.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 167.0,
#      'wspd': 19.8,
#      'wpgt': None,
#      'pres': 1022.1,
#      'tsun': None},
#     {'date': '2019-05-26',
#      'tavg': 19.9,
#      'tmin': 15.0,
#      'tmax': 29.4,
#      'prcp': 3.8,
#      'snow': 0.0,
#      'wdir': 234.0,
#      'wspd': 16.2,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None},
#     {'date': '2019-05-27',
#      'tavg': 22.8,
#      'tmin': 17.8,
#      'tmax': 27.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 340.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None},
#     {'date': '2019-05-28',
#      'tavg': 18.4,
#      'tmin': 16.7,
#      'tmax': 21.7,
#      'prcp': 3.0,
#      'snow': 0.0,
#      'wdir': 163.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1010.0,
#      'tsun': None},
#     {'date': '2019-05-29',
#      'tavg': 18.0,
#      'tmin': 13.3,
#      'tmax': 21.7,
#      'prcp': 10.9,
#      'snow': 0.0,
#      'wdir': 100.0,
#      'wspd': 14.4,
#      'wpgt': None,
#      'pres': 1006.8,
#      'tsun': None},
#     {'date': '2019-05-30',
#      'tavg': 14.8,
#      'tmin': 13.3,
#      'tmax': 17.8,
#      'prcp': 31.2,
#      'snow': 0.0,
#      'wdir': 108.0,
#      'wspd': 10.1,
#      'wpgt': None,
#      'pres': 1008.1,
#      'tsun': None},
#     {'date': '2019-05-31',
#      'tavg': 20.6,
#      'tmin': 16.1,
#      'tmax': 26.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 230.0,
#      'wspd': 16.2,
#      'wpgt': None,
#      'pres': 1007.3,
#      'tsun': None},
#     {'date': '2019-06-01',
#      'tavg': 20.1,
#      'tmin': 16.1,
#      'tmax': 25.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 123.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1009.8,
#      'tsun': None},
#     {'date': '2019-06-02',
#      'tavg': 20.1,
#      'tmin': 16.7,
#      'tmax': 26.1,
#      'prcp': 6.4,
#      'snow': 0.0,
#      'wdir': 171.0,
#      'wspd': 13.7,
#      'wpgt': None,
#      'pres': 1006.7,
#      'tsun': None},
#     {'date': '2019-06-03',
#      'tavg': 19.2,
#      'tmin': 13.9,
#      'tmax': 22.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 299.0,
#      'wspd': 20.9,
#      'wpgt': None,
#      'pres': 1012.1,
#      'tsun': None},
#     {'date': '2019-06-04',
#      'tavg': 16.9,
#      'tmin': 12.8,
#      'tmax': 21.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 262.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1018.6,
#      'tsun': None},
#     {'date': '2019-06-05',
#      'tavg': 19.6,
#      'tmin': 16.7,
#      'tmax': 23.9,
#      'prcp': 4.1,
#      'snow': 0.0,
#      'wdir': 196.0,
#      'wspd': 19.8,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None},
#     {'date': '2019-06-06',
#      'tavg': 22.6,
#      'tmin': 17.8,
#      'tmax': 28.9,
#      'prcp': 11.7,
#      'snow': 0.0,
#      'wdir': 238.0,
#      'wspd': 13.7,
#      'wpgt': None,
#      'pres': 1007.2,
#      'tsun': None},
#     {'date': '2019-06-07',
#      'tavg': 21.4,
#      'tmin': 16.1,
#      'tmax': 25.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 67.0,
#      'wspd': 9.7,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': None},
#     {'date': '2019-06-08',
#      'tavg': 19.8,
#      'tmin': 15.6,
#      'tmax': 25.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 79.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1020.2,
#      'tsun': None},
#     {'date': '2019-06-09',
#      'tavg': 18.6,
#      'tmin': 13.9,
#      'tmax': 23.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 72.0,
#      'wspd': 18.0,
#      'wpgt': None,
#      'pres': 1025.7,
#      'tsun': None},
#     {'date': '2019-06-10',
#      'tavg': 17.4,
#      'tmin': 13.3,
#      'tmax': 21.1,
#      'prcp': 11.7,
#      'snow': 0.0,
#      'wdir': 90.0,
#      'wspd': 18.7,
#      'wpgt': None,
#      'pres': 1018.3,
#      'tsun': None},
#     {'date': '2019-06-11',
#      'tavg': 21.3,
#      'tmin': 18.3,
#      'tmax': 26.1,
#      'prcp': 5.1,
#      'snow': 0.0,
#      'wdir': 304.0,
#      'wspd': 26.3,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None},
#     {'date': '2019-06-12',
#      'tavg': 19.6,
#      'tmin': 13.9,
#      'tmax': 22.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 100.0,
#      'wspd': 15.8,
#      'wpgt': None,
#      'pres': 1021.3,
#      'tsun': None},
#     {'date': '2019-06-13',
#      'tavg': 16.6,
#      'tmin': 13.9,
#      'tmax': 18.9,
#      'prcp': 16.3,
#      'snow': 0.0,
#      'wdir': 73.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1011.3,
#      'tsun': None},
#     {'date': '2019-06-14',
#      'tavg': 18.3,
#      'tmin': 15.0,
#      'tmax': 23.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 252.0,
#      'wspd': 24.5,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None},
#     {'date': '2019-06-15',
#      'tavg': 19.9,
#      'tmin': 12.8,
#      'tmax': 23.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 208.0,
#      'wspd': 23.0,
#      'wpgt': None,
#      'pres': 1018.4,
#      'tsun': None},
#     {'date': '2019-06-16',
#      'tavg': 20.6,
#      'tmin': 18.3,
#      'tmax': 24.4,
#      'prcp': 3.0,
#      'snow': 0.0,
#      'wdir': 194.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1012.1,
#      'tsun': None},
#     {'date': '2019-06-17',
#      'tavg': 21.8,
#      'tmin': 19.4,
#      'tmax': 24.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 166.0,
#      'wspd': 9.0,
#      'wpgt': None,
#      'pres': 1014.3,
#      'tsun': None},
#     {'date': '2019-06-18',
#      'tavg': 20.7,
#      'tmin': 18.9,
#      'tmax': 24.4,
#      'prcp': 35.1,
#      'snow': 0.0,
#      'wdir': 130.0,
#      'wspd': 8.6,
#      'wpgt': None,
#      'pres': 1013.4,
#      'tsun': None},
#     {'date': '2019-06-19',
#      'tavg': 19.5,
#      'tmin': 18.3,
#      'tmax': 20.6,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 86.0,
#      'wspd': 12.6,
#      'wpgt': None,
#      'pres': 1010.8,
#      'tsun': None},
#     {'date': '2019-06-20',
#      'tavg': 20.4,
#      'tmin': 18.9,
#      'tmax': 24.4,
#      'prcp': 19.1,
#      'snow': 0.0,
#      'wdir': 150.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1002.4,
#      'tsun': None},
#     {'date': '2019-06-21',
#      'tavg': 22.2,
#      'tmin': 18.9,
#      'tmax': 26.7,
#      'prcp': 14.7,
#      'snow': 0.0,
#      'wdir': 315.0,
#      'wspd': 23.0,
#      'wpgt': None,
#      'pres': 1001.8,
#      'tsun': None},
#     {'date': '2019-06-22',
#      'tavg': 22.6,
#      'tmin': 17.2,
#      'tmax': 27.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 319.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1011.8,
#      'tsun': None},
#     {'date': '2019-06-23',
#      'tavg': 23.5,
#      'tmin': 17.8,
#      'tmax': 29.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 288.0,
#      'wspd': 19.8,
#      'wpgt': None,
#      'pres': 1014.4,
#      'tsun': None},
#     {'date': '2019-06-24',
#      'tavg': 23.9,
#      'tmin': 17.2,
#      'tmax': 28.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 215.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1011.6,
#      'tsun': None},
#     {'date': '2019-06-25',
#      'tavg': 22.7,
#      'tmin': 20.6,
#      'tmax': 27.2,
#      'prcp': 5.3,
#      'snow': 0.0,
#      'wdir': 151.0,
#      'wspd': 10.4,
#      'wpgt': None,
#      'pres': 1010.3,
#      'tsun': None},
#     {'date': '2019-06-26',
#      'tavg': 24.7,
#      'tmin': 20.6,
#      'tmax': 30.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 253.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None},
#     {'date': '2019-06-27',
#      'tavg': 25.8,
#      'tmin': 20.6,
#      'tmax': 32.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 220.0,
#      'wspd': 10.4,
#      'wpgt': None,
#      'pres': 1019.3,
#      'tsun': None},
#     {'date': '2019-06-28',
#      'tavg': 26.0,
#      'tmin': 20.6,
#      'tmax': 31.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 130.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1020.9,
#      'tsun': None},
#     {'date': '2019-06-29',
#      'tavg': 25.4,
#      'tmin': 21.7,
#      'tmax': 31.7,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 211.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1015.3,
#      'tsun': None},
#     {'date': '2019-06-30',
#      'tavg': 25.3,
#      'tmin': 20.6,
#      'tmax': 30.6,
#      'prcp': 1.5,
#      'snow': 0.0,
#      'wdir': 302.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1008.6,
#      'tsun': None},
#     {'date': '2019-07-01',
#      'tavg': 23.8,
#      'tmin': 18.3,
#      'tmax': 30.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 314.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1012.6,
#      'tsun': None},
#     {'date': '2019-07-02',
#      'tavg': 25.4,
#      'tmin': 19.4,
#      'tmax': 31.7,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 219.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1010.0,
#      'tsun': None},
#     {'date': '2019-07-03',
#      'tavg': 26.1,
#      'tmin': 22.2,
#      'tmax': 30.0,
#      'prcp': 1.5,
#      'snow': 0.0,
#      'wdir': 222.0,
#      'wspd': 9.0,
#      'wpgt': None,
#      'pres': 1010.9,
#      'tsun': None},
#     {'date': '2019-07-04',
#      'tavg': 25.3,
#      'tmin': 21.1,
#      'tmax': 30.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 117.0,
#      'wspd': 9.7,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None},
#     {'date': '2019-07-05',
#      'tavg': 24.3,
#      'tmin': 22.2,
#      'tmax': 28.3,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 131.0,
#      'wspd': 11.5,
#      'wpgt': None,
#      'pres': 1020.4,
#      'tsun': None},
#     {'date': '2019-07-06',
#      'tavg': 25.9,
#      'tmin': 23.9,
#      'tmax': 30.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 198.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None},
#     {'date': '2019-07-07',
#      'tavg': 25.7,
#      'tmin': 21.1,
#      'tmax': 29.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 67.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1012.4,
#      'tsun': None},
#     {'date': '2019-07-08',
#      'tavg': 22.4,
#      'tmin': 20.0,
#      'tmax': 25.6,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 131.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1015.3,
#      'tsun': None},
#     {'date': '2019-07-09',
#      'tavg': 24.6,
#      'tmin': 20.0,
#      'tmax': 31.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 238.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None},
#     {'date': '2019-07-10',
#      'tavg': 25.8,
#      'tmin': 21.1,
#      'tmax': 31.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 212.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None},
#     {'date': '2019-07-11',
#      'tavg': 24.9,
#      'tmin': 21.7,
#      'tmax': 28.3,
#      'prcp': 18.3,
#      'snow': 0.0,
#      'wdir': 174.0,
#      'wspd': 17.3,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None},
#     {'date': '2019-07-12',
#      'tavg': 26.2,
#      'tmin': 22.8,
#      'tmax': 32.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 275.0,
#      'wspd': 19.4,
#      'wpgt': None,
#      'pres': 1007.2,
#      'tsun': None},
#     {'date': '2019-07-13',
#      'tavg': 25.8,
#      'tmin': 21.7,
#      'tmax': 29.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 261.0,
#      'wspd': 17.6,
#      'wpgt': None,
#      'pres': 1012.9,
#      'tsun': None},
#     {'date': '2019-07-14',
#      'tavg': 27.4,
#      'tmin': 22.8,
#      'tmax': 33.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 270.0,
#      'wspd': 19.4,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None},
#     {'date': '2019-07-15',
#      'tavg': 25.8,
#      'tmin': 20.6,
#      'tmax': 30.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 297.0,
#      'wspd': 17.6,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None},
#     {'date': '2019-07-16',
#      'tavg': 25.4,
#      'tmin': 21.1,
#      'tmax': 30.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 208.0,
#      'wspd': 17.3,
#      'wpgt': None,
#      'pres': 1017.5,
#      'tsun': None},
#     {'date': '2019-07-17',
#      'tavg': 26.9,
#      'tmin': 22.8,
#      'tmax': 32.2,
#      'prcp': 20.1,
#      'snow': 0.0,
#      'wdir': 198.0,
#      'wspd': 18.0,
#      'wpgt': None,
#      'pres': 1013.9,
#      'tsun': None},
#     {'date': '2019-07-18',
#      'tavg': 25.3,
#      'tmin': 21.7,
#      'tmax': 30.0,
#      'prcp': 2.3,
#      'snow': 0.0,
#      'wdir': 128.0,
#      'wspd': 11.9,
#      'wpgt': None,
#      'pres': 1012.3,
#      'tsun': None},
#     {'date': '2019-07-19',
#      'tavg': 24.3,
#      'tmin': 21.7,
#      'tmax': 28.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 191.0,
#      'wspd': 13.7,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None},
#     {'date': '2019-07-20',
#      'tavg': 30.0,
#      'tmin': 25.6,
#      'tmax': 37.2,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 230.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1010.3,
#      'tsun': None},
#     {'date': '2019-07-21',
#      'tavg': 31.9,
#      'tmin': 26.7,
#      'tmax': 37.2,
#      'prcp': 0.8,
#      'snow': 0.0,
#      'wdir': 251.0,
#      'wspd': 18.7,
#      'wpgt': None,
#      'pres': 1008.9,
#      'tsun': None},
#     {'date': '2019-07-22',
#      'tavg': 28.7,
#      'tmin': 22.8,
#      'tmax': 30.6,
#      'prcp': 40.4,
#      'snow': 0.0,
#      'wdir': 115.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1009.3,
#      'tsun': None},
#     {'date': '2019-07-23',
#      'tavg': 22.6,
#      'tmin': 19.4,
#      'tmax': 24.4,
#      'prcp': 52.6,
#      'snow': 0.0,
#      'wdir': 29.0,
#      'wspd': 13.7,
#      'wpgt': None,
#      'pres': 1009.8,
#      'tsun': None},
#     {'date': '2019-07-24',
#      'tavg': 22.9,
#      'tmin': 18.3,
#      'tmax': 28.9,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 50.0,
#      'wspd': 11.9,
#      'wpgt': None,
#      'pres': 1013.8,
#      'tsun': None},
#     {'date': '2019-07-25',
#      'tavg': 24.3,
#      'tmin': 19.4,
#      'tmax': 29.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 282.0,
#      'wspd': 12.6,
#      'wpgt': None,
#      'pres': 1019.1,
#      'tsun': None},
#     {'date': '2019-07-26',
#      'tavg': 24.9,
#      'tmin': 19.4,
#      'tmax': 29.4,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 188.0,
#      'wspd': 10.8,
#      'wpgt': None,
#      'pres': 1024.0,
#      'tsun': None},
#     {'date': '2019-07-27',
#      'tavg': 24.7,
#      'tmin': 21.1,
#      'tmax': 27.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 178.0,
#      'wspd': 15.1,
#      'wpgt': None,
#      'pres': 1024.2,
#      'tsun': None},
#     {'date': '2019-07-28',
#      'tavg': 25.8,
#      'tmin': 21.7,
#      'tmax': 30.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 214.0,
#      'wspd': 19.8,
#      'wpgt': None,
#      'pres': 1019.2,
#      'tsun': None},
#     {'date': '2019-07-29',
#      'tavg': 27.0,
#      'tmin': 22.2,
#      'tmax': 31.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 211.0,
#      'wspd': 16.2,
#      'wpgt': None,
#      'pres': 1015.9,
#      'tsun': None},
#     {'date': '2019-07-30',
#      'tavg': 27.1,
#      'tmin': 23.9,
#      'tmax': 30.6,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 199.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None},
#     {'date': '2019-07-31',
#      'tavg': 25.4,
#      'tmin': 22.2,
#      'tmax': 30.0,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 201.0,
#      'wspd': 11.5,
#      'wpgt': None,
#      'pres': 1016.6,
#      'tsun': None},
#     {'date': '2019-08-01',
#      'tavg': 25.4,
#      'tmin': 21.7,
#      'tmax': 31.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 357.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1018.3,
#      'tsun': None},
#     {'date': '2019-08-02',
#      'tavg': 25.1,
#      'tmin': 22.2,
#      'tmax': 27.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 151.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1019.9,
#      'tsun': None},
#     {'date': '2019-08-03',
#      'tavg': 25.0,
#      'tmin': 21.1,
#      'tmax': 28.9,
#      'prcp': 0.3,
#      'snow': 0.0,
#      'wdir': 194.0,
#      'wspd': 15.5,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None},
#     {'date': '2019-08-04',
#      'tavg': 25.9,
#      'tmin': 21.1,
#      'tmax': 31.7,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 247.0,
#      'wspd': 10.4,
#      'wpgt': None,
#      'pres': 1013.0,
#      'tsun': None},
#     {'date': '2019-08-05',
#      'tavg': 24.7,
#      'tmin': 21.1,
#      'tmax': 27.8,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 74.0,
#      'wspd': 12.2,
#      'wpgt': None,
#      'pres': 1014.9,
#      'tsun': None},
#     {'date': '2019-08-06',
#      'tavg': 23.5,
#      'tmin': 21.7,
#      'tmax': 26.1,
#      'prcp': 0.0,
#      'snow': 0.0,
#      'wdir': 109.0,
#      'wspd': 11.9,
# ...
#      'tsun': None},
#     {'date': '2021-07-16',
#      'tavg': 15.8,
#      'tmin': 11.4,
#      'tmax': 20.2,
#      'prcp': 0.1,
#      'snow': None,
#      'wdir': 78.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1024.4,
#      'tsun': None},
#     {'date': '2021-07-17',
#      'tavg': 15.6,
#      'tmin': 11.4,
#      'tmax': 20.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 83.0,
#      'wspd': 9.0,
#      'wpgt': None,
#      'pres': 1024.1,
#      'tsun': None},
#     {'date': '2021-07-18',
#      'tavg': 15.9,
#      'tmin': 12.7,
#      'tmax': 20.9,
#      'prcp': 0.1,
#      'snow': None,
#      'wdir': 72.0,
#      'wspd': 9.3,
#      'wpgt': None,
#      'pres': 1023.8,
#      'tsun': None},
#     {'date': '2021-07-19',
#      'tavg': 15.2,
#      'tmin': 10.6,
#      'tmax': 21.7,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 59.0,
#      'wspd': 9.6,
#      'wpgt': None,
#      'pres': 1023.0,
#      'tsun': None},
#     {'date': '2021-07-20',
#      'tavg': 15.0,
#      'tmin': 9.0,
#      'tmax': 20.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 43.0,
#      'wspd': 10.1,
#      'wpgt': None,
#      'pres': 1022.7,
#      'tsun': None},
#     {'date': '2021-07-21',
#      'tavg': 16.8,
#      'tmin': 10.3,
#      'tmax': 23.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 11.0,
#      'wspd': 9.7,
#      'wpgt': None,
#      'pres': 1022.8,
#      'tsun': None},
#     {'date': '2021-07-22',
#      'tavg': 17.7,
#      'tmin': 11.2,
#      'tmax': 24.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 172.0,
#      'wspd': 8.8,
#      'wpgt': None,
#      'pres': 1022.1,
#      'tsun': None},
#     {'date': '2021-07-23',
#      'tavg': 18.0,
#      'tmin': 13.7,
#      'tmax': 23.7,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 75.0,
#      'wspd': 14.3,
#      'wpgt': None,
#      'pres': 1022.7,
#      'tsun': None},
#     {'date': '2021-07-24',
#      'tavg': 14.9,
#      'tmin': 10.4,
#      'tmax': 21.1,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 73.0,
#      'wspd': 17.7,
#      'wpgt': None,
#      'pres': 1026.4,
#      'tsun': None},
#     {'date': '2021-07-25',
#      'tavg': 13.1,
#      'tmin': 7.9,
#      'tmax': 19.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 91.0,
#      'wspd': 15.2,
#      'wpgt': None,
#      'pres': 1027.9,
#      'tsun': None},
#     {'date': '2021-07-26',
#      'tavg': 12.7,
#      'tmin': 6.8,
#      'tmax': 19.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 89.0,
#      'wspd': 15.4,
#      'wpgt': None,
#      'pres': 1026.7,
#      'tsun': None},
#     {'date': '2021-07-27',
#      'tavg': 13.5,
#      'tmin': 8.5,
#      'tmax': 19.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 15.3,
#      'wpgt': None,
#      'pres': 1024.5,
#      'tsun': None},
#     {'date': '2021-07-28',
#      'tavg': 13.3,
#      'tmin': 7.6,
#      'tmax': 19.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 14.9,
#      'wpgt': None,
#      'pres': 1022.7,
#      'tsun': None},
#     {'date': '2021-07-29',
#      'tavg': 14.5,
#      'tmin': 8.5,
#      'tmax': 21.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 71.0,
#      'wspd': 10.2,
#      'wpgt': None,
#      'pres': 1022.8,
#      'tsun': None},
#     {'date': '2021-07-30',
#      'tavg': 15.1,
#      'tmin': 9.2,
#      'tmax': 22.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 83.0,
#      'wspd': 13.4,
#      'wpgt': None,
#      'pres': 1024.9,
#      'tsun': None},
#     {'date': '2021-07-31',
#      'tavg': 15.4,
#      'tmin': 9.3,
#      'tmax': 22.1,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 78.0,
#      'wspd': 18.6,
#      'wpgt': None,
#      'pres': 1026.8,
#      'tsun': None},
#     {'date': '2021-08-01',
#      'tavg': 15.9,
#      'tmin': 10.9,
#      'tmax': 22.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 57.0,
#      'wspd': 14.2,
#      'wpgt': None,
#      'pres': 1025.1,
#      'tsun': None},
#     {'date': '2021-08-02',
#      'tavg': 16.5,
#      'tmin': 10.1,
#      'tmax': 23.7,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 75.0,
#      'wspd': 8.2,
#      'wpgt': None,
#      'pres': 1022.7,
#      'tsun': None},
#     {'date': '2021-08-03',
#      'tavg': 16.6,
#      'tmin': 11.2,
#      'tmax': 23.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 61.0,
#      'wspd': 13.6,
#      'wpgt': None,
#      'pres': 1023.1,
#      'tsun': None},
#     {'date': '2021-08-04',
#      'tavg': 15.6,
#      'tmin': 10.0,
#      'tmax': 22.6,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 73.0,
#      'wspd': 14.1,
#      'wpgt': None,
#      'pres': 1024.0,
#      'tsun': None},
#     {'date': '2021-08-05',
#      'tavg': 16.2,
#      'tmin': 10.6,
#      'tmax': 23.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 45.0,
#      'wspd': 9.1,
#      'wpgt': None,
#      'pres': 1022.7,
#      'tsun': None},
#     {'date': '2021-08-06',
#      'tavg': 16.8,
#      'tmin': 9.6,
#      'tmax': 24.2,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 47.0,
#      'wspd': 8.6,
#      'wpgt': None,
#      'pres': 1020.8,
#      'tsun': None},
#     {'date': '2021-08-07',
#      'tavg': 18.5,
#      'tmin': 9.9,
#      'tmax': 26.1,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 56.0,
#      'wspd': 7.8,
#      'wpgt': None,
#      'pres': 1019.8,
#      'tsun': None},
#     {'date': '2021-08-08',
#      'tavg': 18.1,
#      'tmin': 12.4,
#      'tmax': 26.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 11.6,
#      'wpgt': None,
#      'pres': 1020.8,
#      'tsun': None},
#     {'date': '2021-08-09',
#      'tavg': 18.0,
#      'tmin': 11.8,
#      'tmax': 25.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 103.0,
#      'wspd': 9.3,
#      'wpgt': None,
#      'pres': 1019.8,
#      'tsun': None},
#     {'date': '2021-08-10',
#      'tavg': 19.1,
#      'tmin': 12.3,
#      'tmax': 26.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 48.0,
#      'wspd': 11.9,
#      'wpgt': None,
#      'pres': 1019.3,
#      'tsun': None},
#     {'date': '2021-08-11',
#      'tavg': 17.0,
#      'tmin': 11.2,
#      'tmax': 24.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 75.0,
#      'wspd': 17.1,
#      'wpgt': None,
#      'pres': 1020.8,
#      'tsun': None},
#     {'date': '2021-08-12',
#      'tavg': 17.4,
#      'tmin': 11.7,
#      'tmax': 24.6,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 54.0,
#      'wspd': 11.3,
#      'wpgt': None,
#      'pres': 1018.8,
#      'tsun': None},
#     {'date': '2021-08-13',
#      'tavg': 19.3,
#      'tmin': 12.5,
#      'tmax': 27.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 73.0,
#      'wspd': 13.1,
#      'wpgt': None,
#      'pres': 1019.2,
#      'tsun': None},
#     {'date': '2021-08-14',
#      'tavg': 18.3,
#      'tmin': 12.9,
#      'tmax': 24.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 84.0,
#      'wspd': 22.1,
#      'wpgt': None,
#      'pres': 1022.8,
#      'tsun': None},
#     {'date': '2021-08-15',
#      'tavg': 16.2,
#      'tmin': 13.0,
#      'tmax': 20.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 73.0,
#      'wspd': 18.6,
#      'wpgt': None,
#      'pres': 1022.9,
#      'tsun': None},
#     {'date': '2021-08-16',
#      'tavg': 15.5,
#      'tmin': 9.6,
#      'tmax': 22.1,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 64.0,
#      'wspd': 17.2,
#      'wpgt': None,
#      'pres': 1022.9,
#      'tsun': None},
#     {'date': '2021-08-17',
#      'tavg': 16.2,
#      'tmin': 10.1,
#      'tmax': 23.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 56.0,
#      'wspd': 16.4,
#      'wpgt': None,
#      'pres': 1021.9,
#      'tsun': None},
#     {'date': '2021-08-18',
#      'tavg': 17.4,
#      'tmin': 11.3,
#      'tmax': 24.2,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 37.0,
#      'wspd': 12.1,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None},
#     {'date': '2021-08-19',
#      'tavg': 19.4,
#      'tmin': 11.5,
#      'tmax': 27.8,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 15.0,
#      'wspd': 8.1,
#      'wpgt': None,
#      'pres': 1014.6,
#      'tsun': None},
#     {'date': '2021-08-20',
#      'tavg': 21.0,
#      'tmin': 13.4,
#      'tmax': 27.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 59.0,
#      'wspd': 12.4,
#      'wpgt': None,
#      'pres': 1014.6,
#      'tsun': None},
#     {'date': '2021-08-21',
#      'tavg': 20.7,
#      'tmin': 15.9,
#      'tmax': 26.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 62.0,
#      'wspd': 19.3,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None},
#     {'date': '2021-08-22',
#      'tavg': 19.6,
#      'tmin': 14.6,
#      'tmax': 24.2,
#      'prcp': 0.3,
#      'snow': None,
#      'wdir': 76.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None},
#     {'date': '2021-08-23',
#      'tavg': 19.9,
#      'tmin': 16.3,
#      'tmax': 25.0,
#      'prcp': 0.4,
#      'snow': None,
#      'wdir': 66.0,
#      'wspd': 19.5,
#      'wpgt': None,
#      'pres': 1017.9,
#      'tsun': None},
#     {'date': '2021-08-24',
#      'tavg': 19.9,
#      'tmin': 12.5,
#      'tmax': 25.5,
#      'prcp': 0.1,
#      'snow': None,
#      'wdir': 59.0,
#      'wspd': 16.5,
#      'wpgt': None,
#      'pres': 1017.2,
#      'tsun': None},
#     {'date': '2021-08-25',
#      'tavg': 21.6,
#      'tmin': 15.4,
#      'tmax': 28.7,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 71.0,
#      'wspd': 16.3,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None},
#     {'date': '2021-08-26',
#      'tavg': 20.5,
#      'tmin': 15.1,
#      'tmax': 26.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 69.0,
#      'wspd': 18.3,
#      'wpgt': None,
#      'pres': 1016.7,
#      'tsun': None},
#     {'date': '2021-08-27',
#      'tavg': 20.8,
#      'tmin': 15.4,
#      'tmax': 27.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 15.2,
#      'wpgt': None,
#      'pres': 1015.9,
#      'tsun': None},
#     {'date': '2021-08-28',
#      'tavg': 22.1,
#      'tmin': 14.9,
#      'tmax': 29.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 50.0,
#      'wspd': 9.9,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': None},
#     {'date': '2021-08-29',
#      'tavg': 22.7,
#      'tmin': 15.9,
#      'tmax': 30.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 75.0,
#      'wspd': 13.2,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None},
#     {'date': '2021-08-30',
#      'tavg': 18.0,
#      'tmin': 12.4,
#      'tmax': 24.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 55.0,
#      'wspd': 19.6,
#      'wpgt': None,
#      'pres': 1017.9,
#      'tsun': None},
#     {'date': '2021-08-31',
#      'tavg': 19.9,
#      'tmin': 12.8,
#      'tmax': 28.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 52.0,
#      'wspd': 12.0,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None},
#     {'date': '2021-09-01',
#      'tavg': 22.1,
#      'tmin': 15.5,
#      'tmax': 29.6,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 65.0,
#      'wspd': 14.7,
#      'wpgt': None,
#      'pres': 1015.8,
#      'tsun': None},
#     {'date': '2021-09-02',
#      'tavg': 21.0,
#      'tmin': 16.1,
#      'tmax': 25.2,
#      'prcp': 0.1,
#      'snow': None,
#      'wdir': 67.0,
#      'wspd': 19.5,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None},
#     {'date': '2021-09-03',
#      'tavg': 20.2,
#      'tmin': 14.7,
#      'tmax': 25.0,
#      'prcp': 0.1,
#      'snow': None,
#      'wdir': 59.0,
#      'wspd': 18.6,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None},
#     {'date': '2021-09-04',
#      'tavg': 21.4,
#      'tmin': 16.2,
#      'tmax': 26.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 58.0,
#      'wspd': 16.9,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None},
#     {'date': '2021-09-05',
#      'tavg': 22.1,
#      'tmin': 16.5,
#      'tmax': 28.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 67.0,
#      'wspd': 16.7,
#      'wpgt': None,
#      'pres': 1016.6,
#      'tsun': None},
#     {'date': '2021-09-06',
#      'tavg': 22.0,
#      'tmin': 15.0,
#      'tmax': 27.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 17.0,
#      'wpgt': None,
#      'pres': 1016.2,
#      'tsun': None},
#     {'date': '2021-09-07',
#      'tavg': 22.4,
#      'tmin': 16.9,
#      'tmax': 28.6,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 56.0,
#      'wspd': 17.4,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None},
#     {'date': '2021-09-08',
#      'tavg': 22.2,
#      'tmin': 16.3,
#      'tmax': 29.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 65.0,
#      'wspd': 18.8,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None},
#     {'date': '2021-09-09',
#      'tavg': 21.5,
#      'tmin': 15.0,
#      'tmax': 28.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 72.0,
#      'wspd': 18.8,
#      'wpgt': None,
#      'pres': 1019.6,
#      'tsun': None},
#     {'date': '2021-09-10',
#      'tavg': 20.3,
#      'tmin': 15.2,
#      'tmax': 25.7,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 85.0,
#      'wspd': 20.8,
#      'wpgt': None,
#      'pres': 1022.7,
#      'tsun': None},
#     {'date': '2021-09-11',
#      'tavg': 18.3,
#      'tmin': 13.0,
#      'tmax': 25.1,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 74.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1022.9,
#      'tsun': None},
#     {'date': '2021-09-12',
#      'tavg': 17.8,
#      'tmin': 11.5,
#      'tmax': 24.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 56.0,
#      'wspd': 14.6,
#      'wpgt': None,
#      'pres': 1020.7,
#      'tsun': None},
#     {'date': '2021-09-13',
#      'tavg': 20.4,
#      'tmin': 12.4,
#      'tmax': 26.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 52.0,
#      'wspd': 13.9,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None},
#     {'date': '2021-09-14',
#      'tavg': 22.6,
#      'tmin': 15.9,
#      'tmax': 29.2,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 57.0,
#      'wspd': 14.0,
#      'wpgt': None,
#      'pres': 1015.2,
#      'tsun': None},
#     {'date': '2021-09-15',
#      'tavg': 24.3,
#      'tmin': 18.5,
#      'tmax': 31.1,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 55.0,
#      'wspd': 15.8,
#      'wpgt': None,
#      'pres': 1013.8,
#      'tsun': None},
#     {'date': '2021-09-16',
#      'tavg': 25.1,
#      'tmin': 18.5,
#      'tmax': 32.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 49.0,
#      'wspd': 12.7,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None},
#     {'date': '2021-09-17',
#      'tavg': 26.0,
#      'tmin': 19.6,
#      'tmax': 33.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 58.0,
#      'wspd': 12.4,
#      'wpgt': None,
#      'pres': 1011.8,
#      'tsun': None},
#     {'date': '2021-09-18',
#      'tavg': 22.1,
#      'tmin': 17.4,
#      'tmax': 26.3,
#      'prcp': 0.5,
#      'snow': None,
#      'wdir': 79.0,
#      'wspd': 21.9,
#      'wpgt': None,
#      'pres': 1017.1,
#      'tsun': None},
#     {'date': '2021-09-19',
#      'tavg': 19.1,
#      'tmin': 12.1,
#      'tmax': 26.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 18.9,
#      'wpgt': None,
#      'pres': 1019.4,
#      'tsun': None},
#     {'date': '2021-09-20',
#      'tavg': 20.9,
#      'tmin': 12.7,
#      'tmax': 29.9,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 69.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None},
#     {'date': '2021-09-21',
#      'tavg': 22.9,
#      'tmin': 15.1,
#      'tmax': 32.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 63.0,
#      'wspd': 12.1,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None},
#     {'date': '2021-09-22',
#      'tavg': 22.2,
#      'tmin': 17.0,
#      'tmax': 28.3,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 74.0,
#      'wspd': 21.6,
#      'wpgt': None,
#      'pres': 1018.2,
#      'tsun': None},
#     {'date': '2021-09-23',
#      'tavg': 19.4,
#      'tmin': 13.5,
#      'tmax': 26.7,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 62.0,
#      'wspd': 20.1,
#      'wpgt': None,
#      'pres': 1019.2,
#      'tsun': None},
#     {'date': '2021-09-24',
#      'tavg': 20.3,
#      'tmin': 13.5,
#      'tmax': 27.5,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 54.0,
#      'wspd': 14.9,
#      'wpgt': None,
#      'pres': 1018.3,
#      'tsun': None},
#     {'date': '2021-09-25',
#      'tavg': 22.0,
#      'tmin': 15.4,
#      'tmax': 29.4,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 71.0,
#      'wspd': 14.2,
#      'wpgt': None,
#      'pres': 1017.6,
#      'tsun': None},
#     {'date': '2021-09-26',
#      'tavg': 21.9,
#      'tmin': 15.5,
#      'tmax': 28.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 57.0,
#      'wspd': 15.9,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None},
#     ...]}]}

# %% [markdown]
# ### Make it a dataframe

# %% [markdown]
# this is our raw data, which we now can load into the database

# %%
weatherreport_daily_df = pd.DataFrame(weatherreport_dict)
weatherreport_daily_df
# Out:
#                                         extracted_at airport_code  station_id  \
# 0  <built-in method now of type object at 0x10284...          JFK       74486
# 1  <built-in method now of type object at 0x10284...          MIA       72202
# 2  <built-in method now of type object at 0x10284...          LAX       72295
# 3  <built-in method now of type object at 0x10284...          JNB       68212
# 4  <built-in method now of type object at 0x10284...          HRE       67816
# 5  <built-in method now of type object at 0x10284...          CPT       68816
# 6  <built-in method now of type object at 0x10284...          MPM       67842
# 7  <built-in method now of type object at 0x10284...          LUN       67765
#
#                                       extracted_data
# 0  {'meta': {'generated': '2024-10-10 14:23:06'},...
# 1  {'meta': {'generated': '2024-10-10 14:23:07'},...
# 2  {'meta': {'generated': '2024-10-10 14:23:07'},...
# 3  {'meta': {'generated': '2024-10-10 14:23:08'},...
# 4  {'meta': {'generated': '2024-10-10 14:23:09'},...
# 5  {'meta': {'generated': '2024-10-10 14:23:09'},...
# 6  {'meta': {'generated': '2024-10-10 14:23:10'},...
# 7  {'meta': {'generated': '2024-10-10 14:23:11'},...

# %% [markdown]
# ### SIDEBAR: For the curious and sceptics...

# %% [markdown]
#     In case you can't resist to know what the data looks like when flattened.
#     Here is the preview with pandas. BUT we are not transforming before loading in our pipeline just yet.
#     We Extract and Load the raw JSON.

# %%
pd.json_normalize(weatherreport_daily_df['extracted_data'][0]['data']).head()
# Out:
#          date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# 0  2019-01-01  10.4   4.4  15.0   2.8   0.0  280.0  29.5  None  1010.8  None
# 1  2019-01-02   3.3   1.1   5.0   0.0   0.0   65.0  13.3  None  1025.0  None
# 2  2019-01-03   4.9   1.1   7.8   0.0   0.0  290.0  18.4  None  1015.0  None
# 3  2019-01-04   3.7   1.1   7.2   0.0   0.0  231.0  18.7  None  1014.7  None
# 4  2019-01-05   6.9   5.0   7.8  10.2   0.0   19.0  19.1  None  1001.4  None

# %%
# using pd.json_normalize() twice to get to the weather_stats of one airport under 'data'

df_JFK = pd.json_normalize(pd.json_normalize(weatherreport_daily_df
['extracted_data']).loc[0, 'data'])
df_JFK
# Out:
#             date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  \
# 0     2019-01-01  10.4   4.4  15.0   2.8   0.0  280.0  29.5  None  1010.8
# 1     2019-01-02   3.3   1.1   5.0   0.0   0.0   65.0  13.3  None  1025.0
# 2     2019-01-03   4.9   1.1   7.8   0.0   0.0  290.0  18.4  None  1015.0
# 3     2019-01-04   3.7   1.1   7.2   0.0   0.0  231.0  18.7  None  1014.7
# 4     2019-01-05   6.9   5.0   7.8  10.2   0.0   19.0  19.1  None  1001.4
# ...          ...   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 1456  2022-12-27  -0.9  -2.1   1.7   0.0   0.0  263.0  17.3  None  1025.5
# 1457  2022-12-28   2.1  -2.7   7.2   0.0   0.0  221.0  13.7  None  1026.7
# 1458  2022-12-29   3.7   0.0   7.8   0.0   0.0  223.0  11.5  None  1026.4
# 1459  2022-12-30   5.4   1.1  10.6   0.0   0.0  198.0  10.1  None  1025.1
# 1460  2022-12-31   7.9   5.0  10.6   6.9   0.0   18.0   4.7  None  1015.8
#
#       tsun
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...
# 1456  None
# 1457  None
# 1458  None
# 1459  None
# 1460  None
#
# [1461 rows x 11 columns]

# %% [raw]
# # using pd.json_normalize() twice to get to the weather_stats of one airport under 'data'
#
# df_JFK = pd.json_normalize(pd.json_normalize(weather_daily_df
# ['extracted_data']).loc[0, 'data'])
# df_JFK

# %% [raw]
# #  compare if needed to the JSON for 'JFK', first row
# weather_daily_df.loc[0,'extracted_data']

# %% [markdown]
# > #### Note: we only used up 3 API calls per attempt

# %% [markdown]
# ### Loading the data into the DB

# %% [markdown]
# Now all we need to create a table in your Schema in our database is part of the `weather_daily_df` dataframe.
# We can use pandas' ability to work with SQLAlchemy and "save" the data to the DB using the `.to_sql()` method

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()
 
pg_user = config['POSTGRES_USER'] # align the key labels with your .env file
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
# updating the url
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# creating the engine
engine = create_engine(url, echo=False)

# %%
engine.url # checking the url (pass is hidden)
# Out:
# postgresql://shaunkutsanzira:***@data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com:5432/hh_analytics_24_2

# %%
# defining data types for the DB
dtype_dict = {
    'extracted_at':types.DateTime,
    'airport_code': types.String,
    'station_id': types.Integer,
    'extracted_data':postgres_json
             }

# %%
from datetime import datetime
# Assuming the 'extracted_at' column is generated using a function like `datetime.now`:
weatherreport_daily_df['extracted_at'] = pd.to_datetime(datetime.now())  # Ensure it's a valid datetime

# %%
# writing dataframe to DB
weatherreport_daily_df.to_sql(name = 'weatherreport_daily_raw', 
                       con = engine, 
                       schema = pg_schema, # pandas is allowing to specify, in which schema the table shall be created
                       if_exists='replace', 
                       dtype=dtype_dict,
                       index=False
                      )
# Out:
# 8

# %%
weatherreport_daily_df
# Out:
#                 extracted_at airport_code  station_id  \
# 0 2024-10-10 16:31:53.951458          JFK       74486
# 1 2024-10-10 16:31:53.951458          MIA       72202
# 2 2024-10-10 16:31:53.951458          LAX       72295
# 3 2024-10-10 16:31:53.951458          JNB       68212
# 4 2024-10-10 16:31:53.951458          HRE       67816
# 5 2024-10-10 16:31:53.951458          CPT       68816
# 6 2024-10-10 16:31:53.951458          MPM       67842
# 7 2024-10-10 16:31:53.951458          LUN       67765
#
#                                       extracted_data
# 0  {'meta': {'generated': '2024-10-10 14:23:06'},...
# 1  {'meta': {'generated': '2024-10-10 14:23:07'},...
# 2  {'meta': {'generated': '2024-10-10 14:23:07'},...
# 3  {'meta': {'generated': '2024-10-10 14:23:08'},...
# 4  {'meta': {'generated': '2024-10-10 14:23:09'},...
# 5  {'meta': {'generated': '2024-10-10 14:23:09'},...
# 6  {'meta': {'generated': '2024-10-10 14:23:10'},...
# 7  {'meta': {'generated': '2024-10-10 14:23:11'},...

# %% [markdown]
# If you see a '3' as the result of the last cell. Something should be right. :)
#
# Check in DBeaver if you see a new table in your Schema. Don't forget to refresh your Schema.

# %% [markdown]
# ## Now continue with the hourly data.
